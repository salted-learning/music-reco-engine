# %%
import pandas as pd
import numpy as np
pd.set_option('display.float_format', lambda x: '%.3f' % x)

import matplotlib.pyplot as plt
import seaborn as sns
% matplotlib inline
plt.style.use('fivethirtyeight')

from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors

# %%
df_data = pd.read_table('lastfm-dataset-360K//usersha1-artmbid-artname-plays.tsv',
                         header = None, nrows = 2e7,
                         names = ['users', 'musicbrainz-artist-id', 'artist-name', 'plays'],
                         usecols = ['users', 'artist-name', 'plays'])

df_profile = pd.read_table('lastfm-dataset-360K//usersha1-profile.tsv',
                            header = None,
                            names = ['users', 'gender', 'age', 'country', 'signup'],
                            usecols = ['users', 'country'])

# %%
df_data.shape
# Out:
# (17535655, 3)

# %%
df_profile.shape
# Out:
# (359347, 2)

# %%
#drop null rows
df_data.dropna(inplace = True)

#us users only
us_profile = df_profile.loc[df_profile['country'] == 'United States']
us_data = us_profile.merge(df_data, how = 'left', left_on = 'users', right_on = 'users')

#total plays for an artist
artist_plays = us_data.groupby('artist-name')['plays'].sum().reset_index().rename(columns = {'plays':'total_artist_plays'})
top_artist_plays = artist_plays.loc[artist_plays['total_artist_plays'] > 10000]

#joining user data & profiles
user_data_with_top_total_plays = us_data.merge(top_artist_plays, how = 'inner', left_on = 'artist-name', right_on = 'artist-name')

# %%
#explore artist_plays
top_artist_plays.describe()
# Out:
#        total_artist_plays
# count            7352.000
# mean           104709.808
# std            296115.449
# min             10004.000
# 25%             15818.000
# 50%             29311.000
# 75%             75917.000
# max          10705203.000

# %%
len(top_artist_plays['artist-name'].unique())
# Out:
# 7352

# %%
del([df_data, df_profile])

# %%
top_plays = user_data_with_top_total_plays.groupby(['users','artist-name']).agg({'plays':np.sum, 
                                                                               'total_artist_plays': 'first'}).reset_index()
top_plays.head()
# Out:
#                                       users        artist-name   plays  \
# 0  00007a47085b9aab8af55f52ec8846ac479ac4fe         aesop rock  72.000
# 1  00007a47085b9aab8af55f52ec8846ac479ac4fe                air 178.000
# 2  00007a47085b9aab8af55f52ec8846ac479ac4fe         amon tobin 106.000
# 3  00007a47085b9aab8af55f52ec8846ac479ac4fe  animal collective 203.000
# 4  00007a47085b9aab8af55f52ec8846ac479ac4fe              annie  75.000
#
#    total_artist_plays
# 0          707850.000
# 1         1196750.000
# 2          357637.000
# 3         1808594.000
# 4           68799.000

# %%
wide_user_artists = top_plays.pivot(index = 'artist-name', columns = 'users', values = 'plays').fillna(0)

wide_ua_sparse = csr_matrix(wide_user_artists)

wide_user_artists.head()
# Out:
# users               00007a47085b9aab8af55f52ec8846ac479ac4fe  \
# artist-name
# !!!                                                    0.000
# (hed) planet earth                                     0.000
# *nsync                                                 0.000
# +/-                                                    0.000
# +44                                                    0.000
#
# users               0001a57568309b287363e72dc682e9a170ba6dc2  \
# artist-name
# !!!                                                    0.000
# (hed) planet earth                                     0.000
# *nsync                                                 0.000
# +/-                                                    0.000
# +44                                                    0.000
#
# users               00024b5b85c40f990c28644d53257819980bf6bb  \
# artist-name
# !!!                                                    0.000
# (hed) planet earth                                     0.000
# *nsync                                                 0.000
# +/-                                                    0.000
# +44                                                  394.000
#
# users               0002dd2154072434d26e5409faa591bfb260a01e  \
# artist-name
# !!!                                                    0.000
# (hed) planet earth                                     0.000
# *nsync                                                 0.000
# +/-                                                    0.000
# +44                                                    0.000
#
# users               00032c7933e0eb05f2258f1147ef81a90f2d4d6c  \
# artist-name
# !!!                                                    0.000
# (hed) planet earth                                     0.000
# *nsync                                                 0.000
# +/-                                                    0.000
# +44                                                    0.000
#
# users               00041cbfdd019b5431f926133266cc4ba38219bb  \
# artist-name
# !!!                                                    0.000
# (hed) planet earth                                     0.000
# *nsync                                                 0.000
# +/-                                                    0.000
# +44                                                    0.000
#
# users               000429493d9716b66b02180d208d09b5b89fbe64  \
# artist-name
# !!!                                                    0.000
# (hed) planet earth                                     0.000
# *nsync                                                 0.000
# +/-                                                    0.000
# +44                                                    0.000
#
# users               000701c3c006b091990162635b36b008c504c6a7  \
# artist-name
# !!!                                                    0.000
# (hed) planet earth                                     0.000
# *nsync                                                 0.000
# +/-                                                    0.000
# +44                                                    0.000
#
# users               000752c87a61bc4247f5219b4769c347c0062c8a  \
# artist-name
# !!!                                                    0.000
# (hed) planet earth                                     0.000
# *nsync                                                 0.000
# +/-                                                    0.000
# +44                                                    0.000
#
# users               0008538a0f505f72fdd66af3c4c71aef8d3bdea4  \
# artist-name
# !!!                                                    0.000
# (hed) planet earth                                     0.000
# *nsync                                                 0.000
# +/-                                                    0.000
# +44                                                    0.000
#
# users                                 ...                     \
# artist-name                           ...
# !!!                                   ...
# (hed) planet earth                    ...
# *nsync                                ...
# +/-                                   ...
# +44                                   ...
#
# users               fff58a5c95280b7af63f9c552f9159b58ae5efa3  \
# artist-name
# !!!                                                    0.000
# (hed) planet earth                                     0.000
# *nsync                                                 0.000
# +/-                                                    0.000
# +44                                                    0.000
#
# users               fff694cf332ed701dccbf17f1d9595ba8ad69f22  \
# artist-name
# !!!                                                    0.000
# (hed) planet earth                                     0.000
# *nsync                                                 0.000
# +/-                                                    0.000
# +44                                                    0.000
#
# users               fff69e7cb53568c732909648527a778c31befec8  \
# artist-name
# !!!                                                    0.000
# (hed) planet earth                                     0.000
# *nsync                                                 0.000
# +/-                                                    0.000
# +44                                                    0.000
#
# users               fff820efe22db6c868515436de82af39e013b910  \
# artist-name
# !!!                                                    0.000
# (hed) planet earth                                     0.000
# *nsync                                                 0.000
# +/-                                                    0.000
# +44                                                    0.000
#
# users               fff89b6b5332f0f38996f11c88f908a3924926fe  \
# artist-name
# !!!                                                    0.000
# (hed) planet earth                                     0.000
# *nsync                                                 0.000
# +/-                                                    0.000
# +44                                                    0.000
#
# users               fff9dc65e7f2763a7e8bce8d99cc1491c2ae4c6f  \
# artist-name
# !!!                                                    0.000
# (hed) planet earth                                     0.000
# *nsync                                                 0.000
# +/-                                                    0.000
# +44                                                    0.000
#
# users               fffa9294e858a7c863b5ad363c748c2330d9bd45  \
# artist-name
# !!!                                                    0.000
# (hed) planet earth                                     0.000
# *nsync                                                 0.000
# +/-                                                    0.000
# +44                                                    0.000
#
# users               fffa9d62caff0f038c7a35db70f109b1bba04a1d  \
# artist-name
# !!!                                                    0.000
# (hed) planet earth                                     0.000
# *nsync                                                 0.000
# +/-                                                    0.000
# +44                                                    0.000
#
# users               fffaf6f9a1a3ad8bd0dff7b48b2eb9eef030fdee  \
# artist-name
# !!!                                                    0.000
# (hed) planet earth                                     0.000
# *nsync                                                 0.000
# +/-                                                    0.000
# +44                                                    0.000
#
# users               fffe8c7f952d9b960a56ed4dcb40a415d924b224
# artist-name
# !!!                                                    0.000
# (hed) planet earth                                     0.000
# *nsync                                                 0.000
# +/-                                                    0.000
# +44                                                    0.000
#
# [5 rows x 66903 columns]

# %%
del([top_artist_plays, top_plays, us_data, us_profile, user_data_with_top_total_plays])

# %%
nn = NearestNeighbors(metric = 'cosine')
nn.fit(wide_ua_sparse)
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='cosine',
#          metric_params=None, n_jobs=1, n_neighbors=5, p=2, radius=1.0)

# %%
#'predicting' recommendations

NEIGHBORS = 8

distance, indices = nn.kneighbors(wide_user_artists.loc[wide_user_artists.index == 'the temptations'], n_neighbors = NEIGHBORS)

# %%
#setting up reco dataframe

reco_index = [i[0] for i in wide_user_artists.index[indices]]
reco_columns = [i+1 for i in range(NEIGHBORS-1)]

reco_data = [i[1:] for i in wide_user_artists.index[indices]]
reco_data2 = [i[1:] for i in distance]

pd.DataFrame(reco_data, index = reco_index, columns = reco_columns)
# Out:
#                              1                2                      3  \
# the temptations  the four tops  ten years after  derek and the dominos
#
#                               4        5                      6  \
# the temptations  pete townshend  the who  the derek trucks band
#
#                                   7
# the temptations  the isley brothers

# %%
pd.DataFrame(reco_data2, index = reco_index, columns = reco_columns)
# Out:
#                     1     2     3     4     5     6     7
# the temptations 0.533 0.588 0.654 0.682 0.688 0.695 0.706
